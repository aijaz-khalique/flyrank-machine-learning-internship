# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aijaz-khalique/flyrank-machine-learning-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Refresh / Content Opportunity Scoring lane. I want to find which pages may need attention and should be reviewed first. I chose this lane because the starter pipeline already ranks pages using different data signals, and I want to understand how these signals can help with content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My question is: Which pages should be reviewed first for a possible content refresh?
#
# The decision is which pages deserve attention first. A content or SEO team could then review the page and decide whether to refresh, improve, protect, monitor, or take another action.
#
# A wrong recommendation could waste time on a page that does not need attention, or cause a page with a real problem to be missed.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Average impressions in 90 days:", round(df["impressions_90d"].mean(), 2))
print("Average sessions in 90 days:", round(df["sessions_90d"].mean(), 2))
# Out:
# Number of rows: 30000
# Average impressions in 90 days: 5200.37
# Average sessions in 90 days: 37.07

# %% [markdown]
# The dataset contains 30,000 pages. The pages also have measurable impressions and sessions, which gives useful information for comparing their performance. These numbers make the refresh opportunity worth exploring further.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# I can describe patterns that I observe in the data and use them as directional evidence for decision support.
#
# I cannot claim that the data proves what causes a page to perform better or worse. I also cannot claim that my model predicts Google's algorithm or guarantees that refreshing a page will improve its performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
